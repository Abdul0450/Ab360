# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdul0450/Ab360/blob/main/Decission_Tree_Regression_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: give data in for practies the decision tree regression model

import numpy as np
import pandas as pd

# Sample data for decision tree regression
np.random.seed(0)
n_samples = 100
X = np.sort(5 * np.random.rand(n_samples, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 2 * (0.5 - np.random.rand(int(n_samples / 5)))

# Create a Pandas DataFrame
data = pd.DataFrame({'X': X.ravel(), 'y': y})

# Display the data
print(data.head())
print(data.tail())
# Out:
#           X         y
# 0  0.023477 -0.332158
# 1  0.093949  0.093811
# 2  0.100538  0.100368
# 3  0.101092  0.100920
# 4  0.195939  0.194688
#            X         y
# 95  4.818314 -1.379458
# 96  4.882297 -0.985600
# 97  4.883805 -0.985344
# 98  4.893092 -0.983718
# 99  4.941869 -0.973785

# %%
 X = data[["X"]]
 y = data["y"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.50,random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model=DecisionTreeRegressor()
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn import tree

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(15,10))
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.6295454545454545, 0.9583333333333334, 'x[0] <= 3.159\nsquared_error = 0.387\nsamples = 50\nvalue = 0.201'),
#  Text(0.40454545454545454, 0.875, 'x[0] <= 2.544\nsquared_error = 0.133\nsamples = 37\nvalue = 0.487'),
#  Text(0.5170454545454546, 0.9166666666666667, 'True  '),
#  Text(0.24545454545454545, 0.7916666666666666, 'x[0] <= 0.63\nsquared_error = 0.099\nsamples = 29\nvalue = 0.601'),
#  Text(0.08636363636363636, 0.7083333333333334, 'x[0] <= 0.249\nsquared_error = 0.068\nsamples = 14\nvalue = 0.354'),
#  Text(0.03636363636363636, 0.625, 'x[0] <= 0.059\nsquared_error = 0.042\nsamples = 4\nvalue = 0.014'),
#  Text(0.01818181818181818, 0.5416666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = -0.332'),
#  Text(0.05454545454545454, 0.5416666666666666, 'x[0] <= 0.149\nsquared_error = 0.002\nsamples = 3\nvalue = 0.13'),
#  Text(0.03636363636363636, 0.4583333333333333, 'x[0] <= 0.098\nsquared_error = 0.0\nsamples = 2\nvalue = 0.097'),
# ...

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import  mean_squared_error, r2_score

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mean_absolute_percentage_error(y_pred,y_test)
# Out:
# 0.6001184994306804

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 0.15971402553761893

# %%
r2 = r2_score(y_test, y_pred)
print(f"R-squared: {r2}")
# Out:
# R-squared: 0.745812270516752
